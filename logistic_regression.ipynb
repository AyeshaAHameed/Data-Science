# %% [markdown]
# IMPORTING LIBRARIES

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# LOADING DATASET

# %%
iris =load_iris()
x,y = iris.data , iris.target

# %% [markdown]
# SPLITTING DATA INTO TRAIN AND TEST DATA

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3 ,random_state=42)

# %% [markdown]
# LOGISTIC REGRESSION MODEL TRAINING

# %%
model = LogisticRegression(max_iter=100)
model.fit(x_test,y_test)
y_pred=model.predict(x_test)

# %% [markdown]
# CHECKING ACCURACY AND CALCULATING MEAN_SQUARED_ERROR

# %%
accuracy=accuracy_score(y_test , y_pred)

# %%
print(accuracy)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 0.0

# %% [markdown]
# GRAPH BETWEEN ACTUAL AND PREDICTED VALUES

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,5))
plt.scatter(y_test,y_pred,color='blue',alpha=0.6)
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()])#REFERENCE LINE
xlabel='actual'
ylabel='predicted'

# %%
import pandas as pd

# %%
sepal_length = float(input('enter sepal length'))
sepal_width = float(input('enter sepal width'))
petal_length = float(input('enter petal length'))
petal_width = float(input('enter petal width'))
x_new=[[sepal_length,sepal_width,petal_length,petal_width]]

pred_class=model.predict(x_new)[0]
pred_class_name=iris.target_names[pred_class]

print(pred_class)
pred_class_name
# Out:
# enter sepal length 3
# enter sepal width 4
# enter petal length 4
# enter petal width 5
# 2
# np.str_('virginica')

# %%
pred_class
